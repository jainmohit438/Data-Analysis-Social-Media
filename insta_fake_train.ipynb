# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\MOHIT\Desktop\Intern\try\insta_fake_train.csv")

# %%
data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# ...

# %%
data.tail()
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 571               0                   0             0        0      33
# 572               0                  21             0        0      44
# 573               0                   0             0        0       4
# 574               0                  11             0        0       0
# 575               0                   0             0        0       2
#
#      #followers  #follows  fake
# 571         166       596     1
# ...

# %%
data.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   576.000000            576.000000      576.000000
# mean      0.701389              0.163837        1.460069
# std       0.458047              0.214096        1.052601
# min       0.000000              0.000000        0.000000
# 25%       0.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.310000        2.000000
# max       1.000000              0.920000       12.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            576.000000      576.000000          576.000000    576.000000
# mean               0.036094        0.034722           22.623264      0.116319
# std                0.125121        0.183234           37.702987      0.320886
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %% [markdown]
# # Let's analyse dataset in graph

# %%
sns.countplot(data["#follows"])

# %%
sns.countplot(data["#followers"])

# %%
sns.countplot(data["description length"])

# %%
sns.countplot(data["profile pic"])

# %%
sns.countplot(data["fake"])

# %%
sns.relplot(x="profile pic",y="fake",kind="line",data=data)

# %%
sns.relplot(x="profile pic",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # This shows that slope of public account is more ..and more the probablity of profile pic less the chances of account to be fake

# %%
sns.relplot(x="#posts",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#posts",y="fake",hue="profile pic",kind="line",data=data)

# %%
sns.relplot(x="#posts",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",hue="profile pic",kind="line",data=data)

# %%
sns.relplot(x="#follows",y="fake",hue="profile pic",kind="line",data=data)

# %%
sns.relplot(x="#follows",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # These trends shows that as the no of followers and follows and post increases there are less possibilities of fake..And as account is private or with profile pic this posibility decreases even more

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %%
sns.relplot(x="name==username",y="fake",kind="line",data=data)

# %%
sns.relplot(x="name==username",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="name==username",y="fake",hue="profile pic",kind="line",data=data)

# %% [markdown]
# # As username=name then as account is private and with profile pic possibility of account being fake decreases..

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %%
sns.relplot(x="external URL",y="fake",kind="line",data=data)

# %%
sns.relplot(x="external URL",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="external URL",y="fake",hue="profile pic",kind="line",data=data)

# %% [markdown]
# # As the external URL increases then posibility of account being faked is rare

# %%
sns.relplot(x="description length",y="fake",kind="line",data=data)

# %%
sns.relplot(x="description length",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="description length",y="fake",hue="profile pic",kind="line",data=data)

# %%
sns.relplot(x="nums/length fullname",y="fake",kind="line",data=data)

# %%
sns.relplot(x="nums/length fullname",y="fake",hue="private",kind="line",data=data)

# %%
sns.relplot(x="nums/length fullname",y="fake",hue="profile pic",kind="line",data=data)

# %% [markdown]
# # As the length of fullname increaese beyond a certain length then probability of account being faked rare

# %% [markdown]
# # Conclusion

# %% [markdown]
# # 1.Accounts with more length name have less probablity

# %% [markdown]
# # Accounts with External URL have less chances of being in fake

# %% [markdown]
# # 3.Accounts with more post,followers,follows have less chance of fake
