# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\MOHIT\Desktop\Intern\try\insta_fake_test.csv")

# %%
data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.33               1                  0.33
# 1            1                  0.00               5                  0.00
# 2            1                  0.00               2                  0.00
# 3            1                  0.00               1                  0.00
# 4            1                  0.50               1                  0.00
#
#    name==username  description length  external URL  private  #posts  \
# 0               1                  30             0        1      35
# 1               0                  64             0        1       3
# 2               0                  82             0        1     319
# 3               0                 143             0        1     273
# 4               0                  76             0        1       6
#
#    #followers  #follows  fake
# 0         488       604     0
# 1          35         6     0
# ...

# %%
data.tail()
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 115            1                  0.29               1                   0.0
# 116            1                  0.40               1                   0.0
# 117            1                  0.00               2                   0.0
# 118            0                  0.17               1                   0.0
# 119            1                  0.44               1                   0.0
#
#      name==username  description length  external URL  private  #posts  \
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows  fake
# 115         114       811     1
# ...

# %%
data.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   120.000000            120.000000      120.000000
# mean      0.758333              0.179917        1.550000
# std       0.429888              0.241492        1.187116
# min       0.000000              0.000000        0.000000
# 25%       1.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.330000        2.000000
# max       1.000000              0.890000        9.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            120.000000      120.000000          120.000000    120.000000
# mean               0.071333        0.041667           27.200000      0.100000
# std                0.209429        0.200664           42.588632      0.301258
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %%
sns.relplot(x="profile pic", y="fake",data=data)

# %%
sns.relplot(x="profile pic",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#follows",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",data=data)

# %%
describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-06611a19269c> in <module>
# ----> 1 describe()
#
# NameError: name 'describe' is not defined

# %% [markdown]
# # Lets start Analysing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\MOHIT\Desktop\Intern\try\insta_fake_test.csv")

# %%
data
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
data.head()
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.33               1                  0.33
# 1            1                  0.00               5                  0.00
# 2            1                  0.00               2                  0.00
# 3            1                  0.00               1                  0.00
# 4            1                  0.50               1                  0.00
#
#    name==username  description length  external URL  private  #posts  \
# 0               1                  30             0        1      35
# 1               0                  64             0        1       3
# 2               0                  82             0        1     319
# 3               0                 143             0        1     273
# 4               0                  76             0        1       6
#
#    #followers  #follows  fake
# 0         488       604     0
# 1          35         6     0
# ...

# %%
data.tail()
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 115            1                  0.29               1                   0.0
# 116            1                  0.40               1                   0.0
# 117            1                  0.00               2                   0.0
# 118            0                  0.17               1                   0.0
# 119            1                  0.44               1                   0.0
#
#      name==username  description length  external URL  private  #posts  \
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows  fake
# 115         114       811     1
# ...

# %%
data.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   120.000000            120.000000      120.000000
# mean      0.758333              0.179917        1.550000
# std       0.429888              0.241492        1.187116
# min       0.000000              0.000000        0.000000
# 25%       1.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.330000        2.000000
# max       1.000000              0.890000        9.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            120.000000      120.000000          120.000000    120.000000
# mean               0.071333        0.041667           27.200000      0.100000
# std                0.209429        0.200664           42.588632      0.301258
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %% [markdown]
# # After knowing basic of our data ..Lets analyse it Graphically

# %%
sns.relplot(x="profile pic",y="fake",hue="private",kind="line",data=data)

# %%
sns.catplot(x="profile pic",y="fake",data=data)

# %%
sns.countplot(data["profile pic"])

# %%
sns.countplot(data["fake"])

# %%
sns.relplot(x="profile pic",y="fake",kind="line",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="#follows",y="fake",kind="line",data=data)

# %% [markdown]
# # As the follows increases there are rarely fake accounts

# %%
sns.relplot(x="#follows",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # Private account are almost not fake...but public accunts are frequently fake when they follows less..

# %%
sns.relplot(x="#followers",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # Same same follows

# %%
sns.relplot(x="private",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#followers",y="fake",data=data)

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %%
sns.relplot(x="name==username",y="fake",kind="line",data=data)

# %%
sns.relplot(x="name==username",y="fake",kind="line",hue="private",data=data)

# %%
sns.relplot(x="#posts",y="fake",kind="line",data=data)

# %%
sns.relplot(x="#posts",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # Accounts having name as username and private are not fake ..

# %% [markdown]
# # Accounts with more post and private have very fake accounts

# %%
sns.relplot(x="description length",y="fake",kind="line",data=data)

# %%
sns.relplot(x="description length",y="fake",hue="private",kind="line",data=data)

# %%
data.columns
# Out:
# Index(['profile pic', 'nums/length username', 'fullname words',
#        'nums/length fullname', 'name==username', 'description length',
#        'external URL', 'private', '#posts', '#followers', '#follows', 'fake'],
#       dtype='object')

# %%
sns.relplot(x="external URL",y="fake",kind="line",data=data)

# %%
sns.relplot(x="external URL",y="fake",hue="private",kind="line",data=data)

# %% [markdown]
# # As the external URL increase with non private accounts probablity of account not fake increases

# %% [markdown]
# # Conclusion

# %% [markdown]
# # 1.Private accounts are less fakes

# %% [markdown]
# # 2.Accounts with more follower,following and post are less likely to be fake

# %% [markdown]
# # 3. Accounts with big description are less fake

# %% [markdown]
# # accounts with more external URL are less likely to be fake
